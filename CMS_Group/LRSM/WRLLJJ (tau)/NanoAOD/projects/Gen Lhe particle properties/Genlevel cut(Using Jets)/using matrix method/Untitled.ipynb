# %%
import os
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
#/store/mc/Run3Summer22NanoAODv12/DYto2L-2Jets_MLL-50_PTLL-600_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2022_realistic_v5-v2/2560000/66897238-ed26-4aa4-a027-808ca7b66bc8.root
#/store/mc/Run3Summer22EENanoAODv12/GluGluHto2Zto4Nu_PT-150_M-125_TuneCP5_13p6TeV_powheg-pythia8/NANOAODSIM/130X_mcRun3_2022_realistic_postEE_v6-v2/50000/48835b31-e408-4b36-82a9-fd5e2592dbc3.root
#/store/mc/Run3Summer22EENanoAODv12/WtoLNu-2Jets_PTLNu-600_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2022_realistic_postEE_v6-v1/2560000/ab02a876-1df5-4766-a231-a36f6a885f8a.root

# %%
sample = "/eos/user/s/shjeon/ForShelby/ggF.root"
open_file = uproot.open(sample)
events_ = open_file["Events"]
keys = events_.keys()

met_pt_ = events_["PuppiMET_pt"].array()
met_phi_ = events_["PuppiMET_phi"].array()
jet_pt_ = events_["Jet_pt"].array()
jet_eta_ = events_["Jet_eta"].array()
jet_phi_ = events_["Jet_phi"].array()
jet_id_ = events_["Jet_jetId"].array()
jet_mass_ = events_["Jet_mass"].array()
ele_pt_ = events_["Electron_pt"].array()
ele_eta_ = events_["Electron_eta"].array()
ele_phi_ = events_["Electron_phi"].array()
ele_id_ = events_["Electron_cutBased"].array()
ele_mass_ = events_["Electron_mass"].array()
muo_pt_ = events_["Muon_pt"].array()
muo_eta_ = events_["Muon_eta"].array()
muo_phi_ = events_["Muon_phi"].array()
muo_id_ = events_["Muon_tightId"].array()
muo_mass_ = events_["Muon_mass"].array()

luminum_ = events_["luminosityBlock"].array()
runnum_ = events_["run"].array()
evnum_ = events_["event"].array()

# %%
print(jet_pt_)
print(jet_id_)
mask_jet = (jet_pt_ > 100) & (jet_id_ > 0)
print(mask_jet)
print (jet_pt_[mask_jet])
# Out:
# [[229], [192, 83.7, 82.3, 69.8, 33.1, 24.8, ... 18.5], [138, 85.2, 36.4, 33.1, 20.1]]
# [[6], [6, 6, 6, 6, 6, 6], [6, 6, 6], [6, ... 6, 6], [6, 6, 6, 6, 6], [6, 6, 6, 6, 6]]
# [[True], [True, False, False, False, ... [True, False, False, False, False]]
# [[229], [192], [126], [155], [251], [215, ... [203], [200, 122], [218], [220], [138]]

# %%
MASK_ = (ak.sum(jet_pt_ > 1000, axis=1) > 0) & (ak.sum(jet_id_ > 0, axis=1) > 1) & (ak.sum(ele_pt_ > 100, axis=1) == 2) & (ak.sum(ele_id_ > 2, axis=1) == 2)
#MASK_ = (ak.sum(jet_pt_ > 1000, axis=1) > 0) & (ak.sum(jet_id_ > 0, axis=1) > 1) & (ak.sum(muo_pt_ > 100, axis=1) == 2) & (ak.sum(muo_id_ > 0, axis=1) == 2)
#MASK_ = (ak.sum(jet_pt_ > 1000, axis=1) > 0) & (ak.sum(jet_id_ > 0, axis=1) > 1) & (ak.sum(muo_pt_ > 100, axis=1) == 1) & (ak.sum(muo_id_ > 0, axis=1) == 1) & ((met_pt_ > 400))
#MASK_ = (ak.sum(jet_pt_ > 1000, axis=1) > 0) & (ak.sum(jet_id_ > 0, axis=1) > 1) & (ak.sum(ele_pt_ > 100, axis=1) == 1) & (ak.sum(ele_id_ > 0, axis=1) == 1) & ((met_pt_ > 400))
#MASK_ = (ak.sum(jet_pt_ > 800, axis=1) > 0) & ((met_pt_ > 400))

met_pt = met_pt_[MASK_]
met_phi = met_phi_[MASK_]


jet_pt = jet_pt_[MASK_]
jet_eta = jet_eta_[MASK_]
jet_phi = jet_phi_[MASK_]
jet_id = jet_id_[MASK_]
jet_mass = jet_mass_[MASK_]
ele_pt = ele_pt_[MASK_]
ele_eta = ele_eta_[MASK_]
ele_phi = ele_phi_[MASK_]
ele_id = ele_id_[MASK_]
ele_mass = ele_mass_[MASK_]


muo_pt = muo_pt_[MASK_]
muo_eta = muo_eta_[MASK_]
muo_phi = muo_phi_[MASK_]
muo_id = muo_id_[MASK_]
muo_mass = muo_mass_[MASK_]

luminum = luminum_[MASK_]
runnum = runnum_[MASK_]
evnum = evnum_[MASK_]

# %%
print (met_pt)
#lep = vector.obj(pt=muo_pt[:,0], phi=muo_phi[:,0], eta=muo_eta[:,0], mass=muo_mass[:,0])
#lep = vector.obj(pt=ele_pt[:,0], phi=ele_phi[:,0], eta=ele_eta[:,0], mass=ele_mass[:,0])
jet = vector.obj(pt=jet_pt[:,0], phi=jet_phi[:,0], eta=jet_eta[:,0], mass=jet_mass[:,0])
#dphi = np.abs(lep.phi - jet.phi)
#dphi = ak.where(dphi < math.pi, dphi, 2*math.pi - dphi)
dphi = np.abs(met_phi - jet.phi)
print (dphi)
for i in range(50):
    if (dphi[i] > 2.5):
        print (luminum[i], runnum[i], evnum[i])
#        print (dphi[i], ele_eta[i], ele_phi[i], jet_eta[i], jet_phi[i], met_phi[i])
#        print (dphi[i], muo_eta[i], muo_phi[i], jet_eta[i], jet_phi[i], met_phi[i])
# Out:
# [745, 925, 1.15e+03, 952, 978, 806, ... 1.41e+03, 490, 945, 621, 1.5e+03, 450]
# [3.18, 3.65, 2.9, 3.11, 3.09, 2.97, 3.13, ... 3.14, 2.35, 3.09, 3.15, 3.15, 3.31]
# 1261 1 22848777
# 1261 1 22853674
# 1327 1 24044653
# 1336 1 24213781
# 1377 1 24961046
# 1415 1 25644186
# 1431 1 25940220
# 1434 1 25995760
# 137 1 2480576
# 941 1 17045356
# 941 1 17047475
# 941 1 17061691
# 2040 1 36978237
# 1077 1 19515903
# 1341 1 24303320
# 1468 1 26599832
# 1468 1 26602145
# 1661 1 30116847
# 1676 1 30383246
# 1698 1 30784957
# 1706 1 30926866
# 1707 1 30940989
# 1722 1 31217600
# 1919 1 34779581
# 4048 1 73384619
# 4048 1 73389369
# 4049 1 73398801
# 4049 1 73404264
# 4050 1 73425732
# 4050 1 73425752
# 4125 1 74788066
# 4365 1 79129518
# 4588 1 83178056
# 4588 1 83181364
# 5003 1 90703097
# 5003 1 90708477
# 5075 1 92009637
# 5077 1 92049965
# 5082 1 92141350
# 5083 1 92155868
# 5091 1 92302848
# 5110 1 92650023
# 5117 1 92776328
# 5131 1 93023560
# 5141 1 93205812
# 5148 1 93343515
# 5170 1 93738795
# 5198 1 94235697
# 5222 1 94671454

# %%
#lep1 = vector.obj(pt=ele_pt[:,0], phi=ele_phi[:,0], eta=ele_eta[:,0], mass=ele_mass[:,0])
#lep2 = vector.obj(pt=ele_pt[:,1], phi=ele_phi[:,1], eta=ele_eta[:,1], mass=ele_mass[:,1])
lep1 = vector.obj(pt=muo_pt[:,0], phi=muo_phi[:,0], eta=muo_eta[:,0], mass=muo_mass[:,0])
lep2 = vector.obj(pt=muo_pt[:,1], phi=muo_phi[:,1], eta=muo_eta[:,1], mass=muo_mass[:,1])

zboson = (lep1+lep2)
print (zboson.mass)

jet = vector.obj(pt=jet_pt[:,0], phi=jet_phi[:,0], eta=jet_eta[:,0], mass=jet_mass[:,0])
dphi = np.abs(zboson.phi - jet.phi)
dphi = ak.where(dphi < math.pi, dphi, 2*math.pi - dphi)
print (dphi)

for i in range(500):
    if (dphi[i] > 2.5):
        print (luminum[i], runnum[i], evnum[i])
#        print (dphi[i], ele_eta[i], ele_phi[i], jet_eta[i], jet_phi[i])
        print (dphi[i], muo_eta[i], muo_phi[i], jet_eta[i], jet_phi[i])
# Out:
# [3.1, 2.93e-05, 3.12, 0.00836, 0.00505, ... 0.000441, 0.000283, 0.0122, 2.55e-05]
# 177 1 1613743
# 3.1032302379608154 [-0.108, 0.115, 0.123] [2.64, 2.64, 2.9] [-0.776, -0.0893, 3.81] [-0.462, 2.66, -0.0817]
# 177 1 1616528
# 3.1168622970581055 [0.0133, -0.318, 0.099, 0.104, 0.0957, 0.0997] [0.359, -0.72, 3.13, 3.13, 3.13, 3.13] [0.101, 0.0132, -0.317, -0.0016] [3.12, 0.359, -0.718, 1.57]
# 177 1 1620068
# 3.1378767490386963 [-0.396, -0.606, -0.306, -0.398, -0.274] [-0.965, -0.962, 2.19, 2.13, 2.33] [-0.303, -0.501, 2.78] [2.17, -0.964, 2.52]
# 178 1 1624586
# 3.1168439388275146 [-0.423, -0.369] [-0.57, -0.842] [0.931, -0.408, -1.03, 3.09] [2.5, -0.662, 0.247, 1.66]
# 180 1 1645864
# 3.1270673274993896 [-0.177, -0.277, -0.279, -0.278, -0.271, -0.276, -0.671, -0.277] [-2.47, 0.694, 0.68, 0.687, 0.653, 0.664, -2.19, 0.685] [-0.276, -0.177, -0.722, 2.69] [0.683, -2.47, -2.19, 2.25]
# 393 1 3601682
# 3.115992546081543 [-0.731, -0.954] [-2.31, -2.27] [-0.708, -0.767, 4.85] [0.812, -2.31, 2.61]
# 394 1 3606048
# 3.122037172317505 [1.91, 2.07, 1.61] [1.47, 1.34, 0.485] [0.66, 1.95, -3.09] [-1.68, 1.45, 2.25]
# 395 1 3617035
# 3.1090455055236816 [-0.467, -0.549, 0.728] [-1.21, -1.38, -0.44] [-0.291, -0.488, -3.26, 2.61, -1.97, -4.14, -0.36] [1.86, -1.25, 2.88, 0.157, -1.62, -2.79, -2.05]
# 3.130955457687378 [-0.177, -0.238, 0.45, 0.502, 0.453] [-2.85, -2.98, 0.238, 0.443, 0.278] [0.46, -0.195, -2.81, -2.82] [0.247, -2.88, 0.495, 0.0838]
# 287 1 2626543
# 3.135333299636841 [0.351, 0.379] [-2.77, -2.96] [-0.302, 0.365, -1.84] [0.292, -2.84, 3.11]
# 287 1 2628902
# 3.1206116676330566 [1.42, 1.7, 1.33, 1.42, 1.33] [-1.15, -1.19, 1.95, 2.46, -1.86] [1.32, 1.47, -2.78, -4.76, -3.62] [1.96, -1.16, -0.791, 0.398, 0.612]
# 288 1 2631969
# 3.112602472305298 [-1.05, -1.18, 0.326] [2.4, 2.21, -0.76] [0.238, -1.17, -3.21, 0.943, 3.19] [-0.741, 2.23, 1.77, 2.93, 3.05]
# 288 1 2634163
# 3.1273622512817383 [-0.144, -0.614, 0.112] [0.114, -3.02, 0.233] [-0.613, -0.122, -3.54] [-3.02, 0.124, 1.41]
# 297 1 2714011
# 3.136565923690796 [0.938, 1, 0.829] [1.63, 1.83, 3] [1.36, 0.951, 4.93] [-1.49, 1.66, 2.57]
# 297 1 2716716
# 3.121638298034668 [-0.785, -0.241, -0.244, -0.283, -0.264] [-1.54, 1.62, 1.62, -1.65, 1.43] [-0.237, -0.785, -0.282, -1.12, -2.29] [1.62, -1.54, -1.64, -0.745, -1.04]
# 297 1 2720475
# 3.1179773807525635 [1.89, 2.04] [0.0559, -0.0948] [1.16, 1.96, 0.453] [3.11, -0.00678, -0.891]
# 298 1 2723368
# 3.125361442565918 [0.459, 0.412] [-1.43, -1.54] [-1.31, 0.439, -2.56, 0.475] [1.68, -1.48, 1.5, -0.454]
# 298 1 2725986
# 3.1147561073303223 [-0.256, -0.237] [-1.82, -1.68] [0.923, -0.251, -1.2] [1.38, -1.78, -0.00243]
# 299 1 2732533
# 3.1324236392974854 [-0.487, -0.278, -1.34] [2.27, 2.43, -0.818] [-1.35, -0.413, -1.8, 4.31] [-0.817, 2.33, 2.15, 2.01]
# 299 1 2734775
# 3.1156301498413086 [-0.58, -0.424] [-0.173, -0.0333] [-1.44, -0.549, 0.611] [2.97, -0.144, -2.91]
# 300 1 2744822
# 3.099318027496338 [-0.489, -0.225] [-2.47, -2.57] [-1.39, -0.456, 2.47, -3.73, 2.09, -1.13, -2.61] [0.703, -2.48, -1.44, -2.57, -1.04, 1.17, 1.69]
# 300 1 2749923
# 3.125689744949341 [0.587, 0.774] [0.947, 0.96] [-0.122, 0.656, -2.53] [-2.21, 0.951, 0.829]
# 441 1 4036556
# 3.14072322845459 [0.0698, 0.212] [0.175, 0.118] [0.35, 0.0985, 0.562] [-2.98, 0.164, 0.366]
# 441 1 4038619
# 3.140700578689575 [-0.34, -0.304, -0.0404, -0.131, -0.55] [2.38, 2.57, -0.739, -0.703, -2.94] [-0.0862, -0.336, -0.645, 1.43, 2.51] [-0.732, 2.41, -2.7, 1.22, 2.45]
# 441 1 4039959
# 3.10296893119812 [-0.929, -0.935, -1.46] [-1.37, -1.39, -2.68] [0.609, -0.929, -1.5] [1.73, -1.37, -2.68]
# 441 1 4040134
# 3.125070571899414 [0.267, 0.11, 0.583, 0.106, 0.105, 0.0966, 0.103, 0.101, 0.199] [0.266, -2.89, 0.318, -2.87, -2.89, -2.88, -2.89, -2.87, -2.89] [0.112, 0.287, -3.74, 2.67] [-2.89, 0.269, 1.58, -1.81]
# 442 1 4051102
# 3.132521152496338 [-1.66, -0.988] [0.334, 0.259] [-1.32, -1.66, -0.988, 1.05, 3.09, -0.482] [-2.83, 0.335, 0.262, -0.525, 0.786, 2.71]
# 443 1 4054878
# 3.1304891109466553 [-0.418, -0.444] [2.88, 2.74] [-1.33, -0.427, -0.235] [-0.312, 2.84, 0.632]
# 443 1 4055115
# 3.1104328632354736 [1.58, 1.96, -0.242] [0.409, 0.751, -2.67] [-0.233, 1.58, 1.96, 0.218, -1.27] [-2.67, 0.41, 0.751, -2.61, -1.09]
# 443 1 4058806
# 3.137195587158203 [-0.458, -0.349] [-2.88, -2.75] [1.24, -0.411, -3.67, 1.98] [0.32, -2.83, -0.167, -1.04]
# 444 1 4062901
# 3.135004758834839 [-0.0815, -0.138, -0.884] [-0.86, -0.644, 1.96] [0.271, -0.101, -3.27, 0.153] [2.35, -0.788, -2.65, -1.54]
# 444 1 4069966
# 3.137741804122925 [-1.09, -1.58, 0.0996, 0.0948] [3.01, -2.51, 0.00986, -0.00322] [0.103, -1.09, -1.58, -1.36, 4.94] [-0.00427, 3.01, -2.52, 1.77, 2.1]
# 457 1 4181021
# 3.1364035606384277 [0.527, 0.561, -2.16] [-1.85, -1.98, 0.955] [0.925, 0.545, -3.27] [1.23, -1.91, 0.696]
# 457 1 4183583
# 3.129673719406128 [-0.0988, -0.24, 0.403] [0.421, 0.511, -2.65] [0.386, -0.169, 2.02] [-2.66, 0.466, 2.18]
# 457 1 4184993
# 3.136348009109497 [-0.57, -0.693, -0.08] [-2.93, -2.76, 0.422] [-0.0365, -0.607, -4.75, 2.66, -0.0576] [0.253, -2.88, 1.1, -0.637, -1.79]
# 70 1 641467
# 3.121432304382324 [-0.425, -0.537, -0.237] [-2.38, -2.38, -2.59] [0.577, -0.413, -0.282, 2.64, 3.53, 2.53, -0.109] [0.744, -2.39, 1.33, -0.788, -1.22, -1.41, -1.09]
# 71 1 643089
# 3.1382806301116943 [-0.534, -0.748] [1.78, 1.62] [-0.301, -0.595, 4.97, 3.37, 4.86, 4.33, 4.16] [-1.39, 1.77, 1.05, -0.168, -1.58, -0.0729, 2.1]
# 71 1 643683
# 3.122331380844116 [-0.686, -0.722] [-2.53, -2.37] [-0.684, -0.699, -3.09] [0.645, -2.48, 0.961]
# 72 1 658456
# 2.680938959121704 [1.27, 0.995, 0.64] [-2.28, -2.17, 1.35] [0.646, 1.24, -1.54] [1.34, -2.27, -1.09]
# 113 1 1032000
# 3.128056764602661 [0.249, 0.362, -0.602] [2.47, 2.61, -0.61] [-0.583, 0.352, -0.993, 4.14, 1.1] [-0.637, 2.59, -0.109, -1.73, -0.644]
# 115 1 1048268
# 3.1399123668670654 [1.94, 2.11, 0.509, 0.519, 0.523, 0.515] [-1.56, -1.46, 1.6, 1.61, 1.63, 1.59] [0.518, 2, 3, 3.8] [1.61, -1.53, -3.1, -1.82]
# 116 1 1054808
# 3.136714458465576 [1.87, 1.68, -1.67] [-1.91, -1.99, -1.23] [-0.0683, 1.81] [1.21, -1.94]
# 116 1 1058795
# 3.1339991092681885 [-0.122, -0.384, -0.342, -0.423, -0.423] [-0.108, 3.03, -0.402, 3.01, 2.17] [-0.389, -0.137, -2.74, -0.916, 2.5] [3.03, -0.128, 1.31, -2.05, 2.56]
# 116 1 1060320
# 3.120497941970825 [1.09, 0.942] [2.01, 2.18] [0.439, 1.06, -2.82, 1.17] [-1.11, 2.05, -0.762, -0.939]
# 157 1 1435703
# 3.120684862136841 [1.58, 1.61] [3.12, -2.86] [0.881, 1.59, 1.76, 3.28, -0.112] [0.0486, -3.11, -2.49, -1.48, -2.27]
# 78 1 709614
# 3.105698347091675 [1.57, 1.56, 1.05] [1.26, 1.05, -1.83] [1.09, 1.57, 2.78] [-1.94, 1.17, -1.66]
# 78 1 710330
# 3.0963189601898193 [0.379, 0.553] [-0.692, -0.838] [-0.998, 0.417, 4.67] [2.43, -0.721, -1.05]
# 79 1 717403
# 3.135709047317505 [0.0597, 0.254] [1.06, 1.09] [-0.933, 0.139, -2.35, -3.61] [-2.08, 1.07, -0.819, -1.31]
# 79 1 718011
# 3.095831871032715 [0.0613, 0.247] [-0.42, -0.507] [1.08, 0.143, 3.51, 2.82] [2.73, -0.458, 2.96, -2.2]
# 79 1 719499
# 3.1214566230773926 [-0.514, -0.775] [-0.239, -1.02] [-0.246, -0.514, -0.776] [2.54, -0.24, -1.02]
# 79 1 722777
# 3.134403944015503 [0.234, 0.475, -0.57] [0.695, 0.815, -2.41] [-0.556, 0.34, -3.27, -3.35] [-2.4, 0.746, 1.74, 2.36]
# 80 1 726093
# 3.1369686126708984 [1.08, 0.81] [0.75, 0.669] [0.00892, 0.982, 0.329, 2.18] [-2.43, 0.719, 0.0114, 0.568]
# 80 1 733427
# 3.115069627761841 [1.28, 1.18] [1.52, 1.64] [1.21, 1.23, -3.62] [-1.54, 1.59, -1.31]
# 230 1 2100459
# 3.130574941635132 [-0.153, -0.0561] [-2.53, -2.29] [-0.793, -0.136, -0.533, -2.15] [0.67, -2.48, 0.288, -0.781]
# 230 1 2101355
# 3.120030641555786 [-0.588, -0.46, -0.789, -0.785, -0.665] [-0.639, -0.469, 2.51, 2.53, -2.71] [-0.805, -0.56, 0.104, 3.16, 2.83, 1.94, 3.44] [2.52, -0.599, -0.692, -3.05, 0.815, -0.736, 0.182]
# 230 1 2102595
# 3.1356897354125977 [-0.911, -0.732] [0.426, 0.289] [0.543, -0.876, 3.19] [-2.74, 0.396, -1.71]
# 232 1 2122003
# 3.11181378364563 [-1.75, -1.51, 2.07] [3, 2.94, 2.78] [-0.836, -1.66, 3.21] [-0.136, 2.98, -2.18]
